# %% [markdown]
# <a href="https://colab.research.google.com/github/hemhalatha/ML_projects/blob/main/hyperparameter_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
dataset_path="/content/drive/MyDrive/yolov8"
print(os.listdir(dataset_path))
# Out:
# ['data.yaml', 'README.dataset.txt', 'README.roboflow.txt', 'test', 'train', 'valid']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')


from ultralytics.engine.tuner import Tuner
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
from ultralytics import YOLO

# Load the model
model = YOLO("yolov8n.pt")

# Run hyperparameter tuning
results = model.tune(
    data="/content/drive/MyDrive/yolov8/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune3'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/10 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune3/tune_scatter_plots.png
# Saved runs/detect/tune3/tune_fitness.png
#
# Tuner: 1/10 iterations complete ✅ (591.96s)
# Tuner: Results saved to runs/detect/tune3
# Tuner: Best fitness=0.52125 observed at iteration 1
# ...

# %%
import yaml

# Path to the YAML file (adjust path if needed)
yaml_path = '/content/runs/detect/tune3/best_hyperparameters.yaml'

# Load the YAML
with open(yaml_path, 'r') as file:
    best_hyperparams = yaml.safe_load(file)

print("Best hyperparameters:")
for key, value in best_hyperparams.items():
    print(f"{key}: {value}")
# Out:
# Best hyperparameters:
# lr0: 0.00975
# lrf: 0.01036
# momentum: 0.90873
# weight_decay: 0.00054
# warmup_epochs: 3.03236
# warmup_momentum: 0.83645
# box: 7.15987
# cls: 0.53236
# dfl: 1.4393
# hsv_h: 0.01474
# hsv_s: 0.70067
# hsv_v: 0.35781
# degrees: 0.0
# translate: 0.09655
# scale: 0.4455
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.50031
# bgr: 0.0
# mosaic: 0.98133
# mixup: 0.0
# cutmix: 0.0
# copy_paste: 0.0
